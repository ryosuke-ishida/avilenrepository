# %%
import os
os.environ["PLAIDML_NATIVE_PATH"] = "/Users/ryosuke/anaconda3/envs/kerasenv/lib/libplaidml.dylib"
os.environ["RUNFILES_DIR"] = "/Users/ryosuke/anaconda3/envs/kerasenv/share/plaidml"
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
import plaidml.keras
plaidml.keras.install_backend() #バックエンドに設定
import keras
print(keras.backend.backend()) #Kerasのバックエンドの確認
# Out:
# plaidml

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 100
height = 32
width = 32
channels = 3

#最適化アルゴリズム
#学習を安定させるために重みをclip＆weight decayを用いる
#識別者の学習ではRMSpropを用いたほうが良いとする事例もある
#またlrを非常に小さくする(0.00005以下)場合もある
#rmsp = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
#識別者用＆敵対者用(DCGAN論文では両方Adam)
adam = keras.optimizers.Adam(lr=0.0002, beta_1=0.5, clipvalue=1.0, decay=1e-8)

#DC論文ではすべての重みを以下で初期化している
init = keras.initializers.RandomNormal(stddev=0.02)
# Out:
# INFO:plaidml:Opening device "metal_amd_radeon_pro_5300m.0"

# %%
#生成ネットワーク
generator_input = keras.Input(shape=(latent_dim,))

#潜在変数を4x4 256-channels 特徴マップへ変換
x = layers.Dense(256 * 4 * 4, kernel_initializer=init, bias_initializer='zeros')(generator_input)
x = layers.LeakyReLU(0.2)(x)
x = layers.Reshape((4, 4, 256))(x)

#4x4 256-channelsを8x8 128-channelsの特徴マップへDeconvolutionで変換
x = layers.Conv2DTranspose(128, 5, strides=2, padding='same', kernel_initializer=init, bias_initializer='zeros')(x)
x = layers.LeakyReLU(0.2)(x)

#8x8 128-channelsを16x16 64-channelsの特徴マップへDeconvolutionで変換
x = layers.Conv2DTranspose(64, 5, strides=2, padding='same', kernel_initializer=init, bias_initializer='zeros')(x)
x = layers.LeakyReLU(0.2)(x)

#16x16 64-channelsを32x32 32-channelsの特徴マップへDeconvolutionで変換
x = layers.Conv2DTranspose(32, 5, strides=2, padding='same', kernel_initializer=init, bias_initializer='zeros')(x)
x = layers.LeakyReLU(0.2)(x)

#32x32 32-channelsを３２x32 3-channelsの特徴マップへ変換
x = layers.Conv2D(channels, 5, activation='tanh', padding='same', kernel_initializer=init, bias_initializer='zeros')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              413696
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 4096)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 8, 8, 128)         819328
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 16, 16, 64)        204864
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 32, 32, 32)        51232
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 3)         2403
# =================================================================
# Total params: 1,491,523
# Trainable params: 1,491,523
# Non-trainable params: 0
# _________________________________________________________________

# %%
#識別ネットワーク
#LeakyReLU、Dropout、GlobalAveragedPoolingを使うのがポイント
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(64, 5, strides=2,padding='same',kernel_initializer=init)(discriminator_input)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(128, 5, strides=2,padding='same')(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(256, 5, strides=2,padding='same')(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()


discriminator_optimizer  = adam
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        4864
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         204928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 256)         819456
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 1,029,505
# Trainable params: 1,029,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
#敵対的ネットワーク

#識別ネットワークの学習を止めて
discriminator.trainable = False
#生成ネットワークの学習をする
gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = adam 
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
from keras.preprocessing import image
from keras.datasets import cifar100
from tqdm import tqdm

#cifar10のダウンロード
(x_train, _), (x_test, y_test) = cifar100.load_data(label_mode='fine')

#各ピクセルが[0,1]の値を取るように正規化
#x_train = x_train.astype('float32') / 255.
#x_train = x_train.reshape(x_train.shape + (1,))
#x_test = x_test.astype('float32') / 255.
#x_test = x_test.reshape(x_test.shape + (1,))

#生成者の出力をtanhとしたので
#各ピクセルが[-1,1]の値を取るように正規化
x_train = (x_train.astype('float32')-127.5)/ 127.5
#x_train = x_train.reshape(x_train.shape + (1,))
x_test = (x_test.astype('float32')-127.5)/ 127.5
x_test = x_test.reshape(x_test.shape + (1,))

#DCGAN論文で使われているバッチ数を使う
batch_size = 128


epochs=100
batchSize=batch_size
batchCount = x_train.shape[0] / batchSize
print ('Epochs:', epochs)
print ('Batch size:', batchSize)
print ('Batches per epoch:', batchCount)

# 学習のループ
for e in range(1, epochs+1):
    print('-'*15, 'Epoch %d' % e, '-'*15) 
    #tqdmを使うとプログレスバーが出るがColabだと不安定なので別で代用する
    #for _ in tqdm(range(int(batchCount))): 
    for i in range(int(batchCount)):
        print("\r{0}% [{1}]".format(int(i/(batchCount-1)*100), "*" * int((i+1)/batchCount*50)), end="")
        # 潜在空間からランダムにサンプリング
        random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

        # データを生成する
        generated_images = generator.predict(random_latent_vectors)

        # 観測データと生成データを識別するための入力データをつくる
        real_images = x_train[np.random.randint(0, x_train.shape[0], size=batchSize)]
        combined_images = np.concatenate([generated_images, real_images])

        # 観測データ(0)と生成データ(1)を識別するラベルをつくる
        labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
        
        # ランダムなノイズを加える
        # ラベルを1ではなく0.7-1.2, 0を0-0.3のようなソフトラベルにすることもある
        #labels += 0.05 * np.random.random(labels.shape)
        labels *= 0.9


        #識別ネットワークの学習
        d_loss = discriminator.train_on_batch(combined_images, labels)

        #潜在空間からサンプリング
        random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

        # すべてリアルなデータだと騙すためのラベル(y=0)を生成
        misleading_targets = np.zeros((batch_size, 1))

        # 生成ネットワークの学習
        # min -y*log(D(G(z)))
        a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
        if i==int(batchCount)-1 :
            print("\n") 
            print('discriminator loss: %s' % (d_loss))
            print('adversarial loss  : %s' % (a_loss))
# Out:
# Epochs: 100
# Batch size: 128
# Batches per epoch: 390.625
# --------------- Epoch 1 ---------------
# 0% []
# /Users/ryosuke/anaconda3/envs/kerasenv/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# INFO:plaidml:Analyzing Ops: 121 of 382 operations complete
# 99% [*************************************************]
#
# discriminator loss: 0.4995221
# adversarial loss  : 1.2592163
# --------------- Epoch 2 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.48198628
# adversarial loss  : 1.1029743
# --------------- Epoch 3 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.71069014
# adversarial loss  : 0.99454015
# --------------- Epoch 4 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.514972
# adversarial loss  : 1.3232908
# --------------- Epoch 5 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6410873
# adversarial loss  : 0.7584336
# --------------- Epoch 6 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.5881816
# adversarial loss  : 0.85536456
# --------------- Epoch 7 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6073021
# adversarial loss  : 0.8017612
# --------------- Epoch 8 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6026027
# adversarial loss  : 0.7478366
# --------------- Epoch 9 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6948726
# adversarial loss  : 0.91491264
# --------------- Epoch 10 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6570964
# adversarial loss  : 0.878268
# --------------- Epoch 11 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67911655
# adversarial loss  : 0.78696644
# --------------- Epoch 12 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.63749504
# adversarial loss  : 0.81900907
# --------------- Epoch 13 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.727219
# adversarial loss  : 0.8111124
# --------------- Epoch 14 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6684872
# adversarial loss  : 0.83886385
# --------------- Epoch 15 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.61347204
# adversarial loss  : 0.7360453
# --------------- Epoch 16 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.64745843
# adversarial loss  : 0.8128945
# --------------- Epoch 17 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66457194
# adversarial loss  : 0.8188797
# --------------- Epoch 18 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6487385
# adversarial loss  : 0.76579964
# --------------- Epoch 19 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6457057
# adversarial loss  : 0.7370747
# --------------- Epoch 20 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6650248
# adversarial loss  : 0.665433
# --------------- Epoch 21 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6563076
# adversarial loss  : 0.76353335
# --------------- Epoch 22 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6364218
# adversarial loss  : 0.753566
# --------------- Epoch 23 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65685415
# adversarial loss  : 0.7083882
# --------------- Epoch 24 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.63599455
# adversarial loss  : 0.76578283
# --------------- Epoch 25 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.5940896
# adversarial loss  : 0.75196123
# --------------- Epoch 26 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6425468
# adversarial loss  : 0.6861875
# --------------- Epoch 27 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66084003
# adversarial loss  : 0.6978435
# --------------- Epoch 28 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.68750894
# adversarial loss  : 0.6818228
# --------------- Epoch 29 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6490059
# adversarial loss  : 0.7485485
# --------------- Epoch 30 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6907401
# adversarial loss  : 0.6333236
# --------------- Epoch 31 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6702347
# adversarial loss  : 0.65763146
# --------------- Epoch 32 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6565067
# adversarial loss  : 0.73816097
# --------------- Epoch 33 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6520791
# adversarial loss  : 0.691877
# --------------- Epoch 34 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6650261
# adversarial loss  : 0.7333573
# --------------- Epoch 35 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6723143
# adversarial loss  : 0.6938345
# --------------- Epoch 36 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6438299
# adversarial loss  : 0.66911244
# --------------- Epoch 37 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6630044
# adversarial loss  : 0.650735
# --------------- Epoch 38 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6519029
# adversarial loss  : 0.6562029
# --------------- Epoch 39 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6599214
# adversarial loss  : 0.6825457
# --------------- Epoch 40 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6694906
# adversarial loss  : 0.7081158
# --------------- Epoch 41 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6404067
# adversarial loss  : 0.64925474
# --------------- Epoch 42 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.64719003
# adversarial loss  : 0.63849187
# --------------- Epoch 43 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6637263
# adversarial loss  : 0.67221427
# --------------- Epoch 44 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6526007
# adversarial loss  : 0.63733184
# --------------- Epoch 45 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6796755
# adversarial loss  : 0.643692
# --------------- Epoch 46 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67471695
# adversarial loss  : 0.71454746
# --------------- Epoch 47 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67163557
# adversarial loss  : 0.6904211
# --------------- Epoch 48 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65031946
# adversarial loss  : 0.6813978
# --------------- Epoch 49 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6782032
# adversarial loss  : 0.6643039
# --------------- Epoch 50 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6709585
# adversarial loss  : 0.6412015
# --------------- Epoch 51 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6644198
# adversarial loss  : 0.7119068
# --------------- Epoch 52 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65814793
# adversarial loss  : 0.72029763
# --------------- Epoch 53 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67381346
# adversarial loss  : 0.7990213
# --------------- Epoch 54 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6659025
# adversarial loss  : 0.67747486
# --------------- Epoch 55 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67874324
# adversarial loss  : 0.63109636
# --------------- Epoch 56 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.68098724
# adversarial loss  : 0.6874635
# --------------- Epoch 57 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6793299
# adversarial loss  : 0.6806643
# --------------- Epoch 58 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.7007731
# adversarial loss  : 0.729994
# --------------- Epoch 59 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66951287
# adversarial loss  : 0.68746287
# --------------- Epoch 60 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67501366
# adversarial loss  : 0.67247415
# --------------- Epoch 61 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6823642
# adversarial loss  : 0.7156018
# --------------- Epoch 62 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6733023
# adversarial loss  : 0.64143544
# --------------- Epoch 63 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.679184
# adversarial loss  : 0.6884904
# --------------- Epoch 64 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6741031
# adversarial loss  : 0.69498575
# --------------- Epoch 65 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6640329
# adversarial loss  : 0.7304096
# --------------- Epoch 66 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6761954
# adversarial loss  : 0.66345644
# --------------- Epoch 67 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67641026
# adversarial loss  : 0.64618665
# --------------- Epoch 68 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6630511
# adversarial loss  : 0.6253711
# --------------- Epoch 69 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.68310356
# adversarial loss  : 0.6749696
# --------------- Epoch 70 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6505331
# adversarial loss  : 0.59929323
# --------------- Epoch 71 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6647204
# adversarial loss  : 0.6766113
# --------------- Epoch 72 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65800196
# adversarial loss  : 0.66735655
# --------------- Epoch 73 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66940665
# adversarial loss  : 0.7410902
# --------------- Epoch 74 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.64311564
# adversarial loss  : 0.6804383
# --------------- Epoch 75 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.69702244
# adversarial loss  : 0.6412307
# --------------- Epoch 76 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66139567
# adversarial loss  : 0.7051525
# --------------- Epoch 77 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6838791
# adversarial loss  : 0.74926865
# --------------- Epoch 78 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6632081
# adversarial loss  : 0.657013
# --------------- Epoch 79 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65458316
# adversarial loss  : 0.6748117
# --------------- Epoch 80 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.70479107
# adversarial loss  : 0.6926843
# --------------- Epoch 81 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6534803
# adversarial loss  : 0.6802863
# --------------- Epoch 82 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66424173
# adversarial loss  : 0.69191647
# --------------- Epoch 83 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66216165
# adversarial loss  : 0.6960904
# --------------- Epoch 84 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6595773
# adversarial loss  : 0.6575365
# --------------- Epoch 85 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6692323
# adversarial loss  : 0.71790797
# --------------- Epoch 86 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6664597
# adversarial loss  : 0.6884185
# --------------- Epoch 87 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6837273
# adversarial loss  : 0.6402255
# --------------- Epoch 88 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67147756
# adversarial loss  : 0.71177924
# --------------- Epoch 89 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6620177
# adversarial loss  : 0.66832304
# --------------- Epoch 90 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65468097
# adversarial loss  : 0.694932
# --------------- Epoch 91 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65893054
# adversarial loss  : 0.71789944
# --------------- Epoch 92 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6709739
# adversarial loss  : 0.68214333
# --------------- Epoch 93 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66294914
# adversarial loss  : 0.65091616
# --------------- Epoch 94 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6754564
# adversarial loss  : 0.6830156
# --------------- Epoch 95 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6760081
# adversarial loss  : 0.70277447
# --------------- Epoch 96 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67052674
# adversarial loss  : 0.68745255
# --------------- Epoch 97 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6605073
# adversarial loss  : 0.67794466
# --------------- Epoch 98 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.64544487
# adversarial loss  : 0.73072743
# --------------- Epoch 99 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.64981854
# adversarial loss  : 0.5704424
# --------------- Epoch 100 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.642418
# adversarial loss  : 0.7055421

# %%
import matplotlib.pyplot as plt

#表示するサンプル数
examples=100
#潜在空間からサンプリング
noise = np.random.normal(0, 1, size=[examples, latent_dim])
#画像を生成
generatedImages = generator.predict(noise)

c = (generatedImages - np.min(generatedImages))/np.ptp(generatedImages)

dim=(10, 10)
plt.figure(figsize=(10, 10))
for i in range(c.shape[0]):
    plt.subplot(dim[0], dim[1], i+1)
    plt.imshow(c[i].reshape(height, width, channels), interpolation='nearest', cmap='gray', vmax=1, vmin=0)
    plt.axis('off')
plt.tight_layout()
