# %%
import os
os.environ["PLAIDML_NATIVE_PATH"] = "/Users/ryosuke/anaconda3/envs/kerasenv/lib/libplaidml.dylib"
os.environ["RUNFILES_DIR"] = "/Users/ryosuke/anaconda3/envs/kerasenv/share/plaidml"
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
import plaidml.keras
plaidml.keras.install_backend() #バックエンドに設定
import keras
print(keras.backend.backend()) #Kerasのバックエンドの確認
# Out:
# plaidml

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 100
height = 32
width = 32
channels = 3

#最適化アルゴリズム
#学習を安定させるために重みをclip＆weight decayを用いる
#識別者の学習ではRMSpropを用いたほうが良いとする事例もある
#またlrを非常に小さくする(0.00005以下)場合もある
#rmsp = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
#識別者用＆敵対者用(DCGAN論文では両方Adam)
adam = keras.optimizers.Adam(lr=0.0002, beta_1=0.5, clipvalue=1.0, decay=1e-8)

#DC論文ではすべての重みを以下で初期化している
init = keras.initializers.RandomNormal(stddev=0.02)
# Out:
# INFO:plaidml:Opening device "metal_amd_radeon_pro_5300m.0"

# %%
#生成ネットワーク
generator_input = keras.Input(shape=(latent_dim,))

#潜在変数を4x4 256-channels 特徴マップへ変換
x = layers.Dense(256 * 4 * 4, kernel_initializer=init, bias_initializer='zeros')(generator_input)
x = layers.LeakyReLU(0.2)(x)
x = layers.Reshape((4, 4, 256))(x)

#4x4 256-channelsを8x8 128-channelsの特徴マップへDeconvolutionで変換
x = layers.Conv2DTranspose(128, 5, strides=2, padding='same', kernel_initializer=init, bias_initializer='zeros')(x)
x = layers.LeakyReLU(0.2)(x)

#8x8 128-channelsを16x16 64-channelsの特徴マップへDeconvolutionで変換
x = layers.Conv2DTranspose(64, 5, strides=2, padding='same', kernel_initializer=init, bias_initializer='zeros')(x)
x = layers.LeakyReLU(0.2)(x)

#16x16 64-channelsを32x32 32-channelsの特徴マップへDeconvolutionで変換
x = layers.Conv2DTranspose(32, 5, strides=2, padding='same', kernel_initializer=init, bias_initializer='zeros')(x)
x = layers.LeakyReLU(0.2)(x)

#32x32 32-channelsを３２x32 3-channelsの特徴マップへ変換
x = layers.Conv2D(channels, 5, activation='tanh', padding='same', kernel_initializer=init, bias_initializer='zeros')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              413696
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 4096)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 8, 8, 128)         819328
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 16, 16, 64)        204864
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 32, 32, 32)        51232
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 3)         2403
# =================================================================
# Total params: 1,491,523
# Trainable params: 1,491,523
# Non-trainable params: 0
# _________________________________________________________________

# %%
#識別ネットワーク
#LeakyReLU、Dropout、GlobalAveragedPoolingを使うのがポイント
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(64, 5, strides=2,padding='same',kernel_initializer=init)(discriminator_input)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(128, 5, strides=2,padding='same')(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.Conv2D(256, 5, strides=2,padding='same')(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(0.3)(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()


discriminator_optimizer  = adam
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        4864
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         204928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 256)         819456
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 1,029,505
# Trainable params: 1,029,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
#敵対的ネットワーク

#識別ネットワークの学習を止めて
discriminator.trainable = False
#生成ネットワークの学習をする
gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = adam 
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
from keras.preprocessing import image
from keras.datasets import cifar10
from tqdm import tqdm

#cifar10のダウンロード
(x_train, _), (x_test, y_test) = cifar10.load_data()

#各ピクセルが[0,1]の値を取るように正規化
#x_train = x_train.astype('float32') / 255.
#x_train = x_train.reshape(x_train.shape + (1,))
#x_test = x_test.astype('float32') / 255.
#x_test = x_test.reshape(x_test.shape + (1,))

#生成者の出力をtanhとしたので
#各ピクセルが[-1,1]の値を取るように正規化
x_train = (x_train.astype('float32')-127.5)/ 127.5
#x_train = x_train.reshape(x_train.shape + (1,))
x_test = (x_test.astype('float32')-127.5)/ 127.5
x_test = x_test.reshape(x_test.shape + (1,))

#DCGAN論文で使われているバッチ数を使う
batch_size = 128


epochs=100
batchSize=batch_size
batchCount = x_train.shape[0] / batchSize
print ('Epochs:', epochs)
print ('Batch size:', batchSize)
print ('Batches per epoch:', batchCount)

# 学習のループ
for e in range(1, epochs+1):
    print('-'*15, 'Epoch %d' % e, '-'*15) 
    #tqdmを使うとプログレスバーが出るがColabだと不安定なので別で代用する
    #for _ in tqdm(range(int(batchCount))): 
    for i in range(int(batchCount)):
        print("\r{0}% [{1}]".format(int(i/(batchCount-1)*100), "*" * int((i+1)/batchCount*50)), end="")
        # 潜在空間からランダムにサンプリング
        random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

        # データを生成する
        generated_images = generator.predict(random_latent_vectors)

        # 観測データと生成データを識別するための入力データをつくる
        real_images = x_train[np.random.randint(0, x_train.shape[0], size=batchSize)]
        combined_images = np.concatenate([generated_images, real_images])

        # 観測データ(0)と生成データ(1)を識別するラベルをつくる
        labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
        
        # ランダムなノイズを加える
        # ラベルを1ではなく0.7-1.2, 0を0-0.3のようなソフトラベルにすることもある
        #labels += 0.05 * np.random.random(labels.shape)
        labels *= 0.9


        #識別ネットワークの学習
        d_loss = discriminator.train_on_batch(combined_images, labels)

        #潜在空間からサンプリング
        random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

        # すべてリアルなデータだと騙すためのラベル(y=0)を生成
        misleading_targets = np.zeros((batch_size, 1))

        # 生成ネットワークの学習
        # min -y*log(D(G(z)))
        a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
        if i==int(batchCount)-1 :
            print("\n") 
            print('discriminator loss: %s' % (d_loss))
            print('adversarial loss  : %s' % (a_loss))
# Out:
# Epochs: 100
# Batch size: 128
# Batches per epoch: 390.625
# --------------- Epoch 1 ---------------
# 0% []
# /Users/ryosuke/anaconda3/envs/kerasenv/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# INFO:plaidml:Analyzing Ops: 131 of 382 operations complete
# 99% [*************************************************]
#
# discriminator loss: 0.4854979
# adversarial loss  : 1.0797279
# --------------- Epoch 2 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.5444611
# adversarial loss  : 1.2371361
# --------------- Epoch 3 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6715412
# adversarial loss  : 0.9496345
# --------------- Epoch 4 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.72809935
# adversarial loss  : 1.3005421
# --------------- Epoch 5 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.64809287
# adversarial loss  : 0.86332226
# --------------- Epoch 6 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.58635736
# adversarial loss  : 0.95226073
# --------------- Epoch 7 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.54345185
# adversarial loss  : 1.0056467
# --------------- Epoch 8 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.60499644
# adversarial loss  : 1.004601
# --------------- Epoch 9 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.5183679
# adversarial loss  : 1.1019466
# --------------- Epoch 10 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.62087226
# adversarial loss  : 0.90820223
# --------------- Epoch 11 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.55876136
# adversarial loss  : 0.9309422
# --------------- Epoch 12 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.5874519
# adversarial loss  : 0.8990929
# --------------- Epoch 13 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6214814
# adversarial loss  : 0.94039774
# --------------- Epoch 14 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6148919
# adversarial loss  : 0.921101
# --------------- Epoch 15 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6316915
# adversarial loss  : 1.0578092
# --------------- Epoch 16 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.61026573
# adversarial loss  : 0.864984
# --------------- Epoch 17 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6243248
# adversarial loss  : 0.80386925
# --------------- Epoch 18 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.603521
# adversarial loss  : 0.87090254
# --------------- Epoch 19 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.5691781
# adversarial loss  : 0.8997479
# --------------- Epoch 20 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65982294
# adversarial loss  : 0.80584645
# --------------- Epoch 21 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.5825417
# adversarial loss  : 0.7549033
# --------------- Epoch 22 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6190101
# adversarial loss  : 0.7744608
# --------------- Epoch 23 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6939448
# adversarial loss  : 0.74372923
# --------------- Epoch 24 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.7099894
# adversarial loss  : 0.7521728
# --------------- Epoch 25 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6069232
# adversarial loss  : 0.7362989
# --------------- Epoch 26 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6626111
# adversarial loss  : 0.74657494
# --------------- Epoch 27 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.68857676
# adversarial loss  : 0.6403609
# --------------- Epoch 28 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66307366
# adversarial loss  : 0.6990017
# --------------- Epoch 29 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.7263162
# adversarial loss  : 0.70722634
# --------------- Epoch 30 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6961076
# adversarial loss  : 0.72988665
# --------------- Epoch 31 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6379961
# adversarial loss  : 0.7604517
# --------------- Epoch 32 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6467309
# adversarial loss  : 0.68116605
# --------------- Epoch 33 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6592665
# adversarial loss  : 0.6911394
# --------------- Epoch 34 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6632995
# adversarial loss  : 0.69754374
# --------------- Epoch 35 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.631161
# adversarial loss  : 0.68569386
# --------------- Epoch 36 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.64060795
# adversarial loss  : 0.65495235
# --------------- Epoch 37 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65705526
# adversarial loss  : 0.68175876
# --------------- Epoch 38 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67039686
# adversarial loss  : 0.7019057
# --------------- Epoch 39 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6455494
# adversarial loss  : 0.73117423
# --------------- Epoch 40 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.69859695
# adversarial loss  : 0.77613443
# --------------- Epoch 41 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6512406
# adversarial loss  : 0.64993864
# --------------- Epoch 42 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6772909
# adversarial loss  : 0.65695536
# --------------- Epoch 43 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.68718415
# adversarial loss  : 0.6480708
# --------------- Epoch 44 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.69143045
# adversarial loss  : 0.7253377
# --------------- Epoch 45 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65632534
# adversarial loss  : 0.64306915
# --------------- Epoch 46 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65674925
# adversarial loss  : 0.62527907
# --------------- Epoch 47 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6554743
# adversarial loss  : 0.66309524
# --------------- Epoch 48 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.63917494
# adversarial loss  : 0.69697225
# --------------- Epoch 49 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65419626
# adversarial loss  : 0.70138144
# --------------- Epoch 50 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67747355
# adversarial loss  : 0.6806537
# --------------- Epoch 51 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6468708
# adversarial loss  : 0.6983248
# --------------- Epoch 52 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6703192
# adversarial loss  : 0.6209657
# --------------- Epoch 53 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6459473
# adversarial loss  : 0.70200574
# --------------- Epoch 54 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65066135
# adversarial loss  : 0.66396475
# --------------- Epoch 55 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6501832
# adversarial loss  : 0.6902815
# --------------- Epoch 56 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6412158
# adversarial loss  : 0.7173157
# --------------- Epoch 57 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6650835
# adversarial loss  : 0.6652093
# --------------- Epoch 58 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6763978
# adversarial loss  : 0.6845052
# --------------- Epoch 59 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.68205726
# adversarial loss  : 0.63591564
# --------------- Epoch 60 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65932405
# adversarial loss  : 0.6317518
# --------------- Epoch 61 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6698236
# adversarial loss  : 0.6448641
# --------------- Epoch 62 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6840924
# adversarial loss  : 0.7141669
# --------------- Epoch 63 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6533338
# adversarial loss  : 0.6299546
# --------------- Epoch 64 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6454111
# adversarial loss  : 0.69599557
# --------------- Epoch 65 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66365594
# adversarial loss  : 0.6269486
# --------------- Epoch 66 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6878804
# adversarial loss  : 0.6982264
# --------------- Epoch 67 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6719049
# adversarial loss  : 0.6549644
# --------------- Epoch 68 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65574443
# adversarial loss  : 0.76984024
# --------------- Epoch 69 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65274894
# adversarial loss  : 0.6653555
# --------------- Epoch 70 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66640186
# adversarial loss  : 0.6790714
# --------------- Epoch 71 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65685266
# adversarial loss  : 0.6411722
# --------------- Epoch 72 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66182446
# adversarial loss  : 0.6348265
# --------------- Epoch 73 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65534353
# adversarial loss  : 0.79387486
# --------------- Epoch 74 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65278155
# adversarial loss  : 0.6746526
# --------------- Epoch 75 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6635468
# adversarial loss  : 0.6958357
# --------------- Epoch 76 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67745
# adversarial loss  : 0.6729679
# --------------- Epoch 77 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.67714167
# adversarial loss  : 0.71371067
# --------------- Epoch 78 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6523755
# adversarial loss  : 0.69892174
# --------------- Epoch 79 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6544296
# adversarial loss  : 0.654985
# --------------- Epoch 80 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6688814
# adversarial loss  : 0.69967103
# --------------- Epoch 81 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66158843
# adversarial loss  : 0.6917051
# --------------- Epoch 82 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6644256
# adversarial loss  : 0.7052441
# --------------- Epoch 83 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6611692
# adversarial loss  : 0.70521116
# --------------- Epoch 84 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.65449107
# adversarial loss  : 0.66997164
# --------------- Epoch 85 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.640245
# adversarial loss  : 0.7263496
# --------------- Epoch 86 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6422551
# adversarial loss  : 0.6658679
# --------------- Epoch 87 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.64678323
# adversarial loss  : 0.7453046
# --------------- Epoch 88 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66928786
# adversarial loss  : 0.6943776
# --------------- Epoch 89 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6684668
# adversarial loss  : 0.67166114
# --------------- Epoch 90 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.68067384
# adversarial loss  : 0.69798464
# --------------- Epoch 91 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6826203
# adversarial loss  : 0.6937723
# --------------- Epoch 92 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.651524
# adversarial loss  : 0.7179378
# --------------- Epoch 93 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6621572
# adversarial loss  : 0.6850477
# --------------- Epoch 94 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6645171
# adversarial loss  : 0.68177205
# --------------- Epoch 95 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6754323
# adversarial loss  : 0.70912397
# --------------- Epoch 96 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.66964436
# adversarial loss  : 0.70868206
# --------------- Epoch 97 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6523082
# adversarial loss  : 0.67003655
# --------------- Epoch 98 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.68184066
# adversarial loss  : 0.71473193
# --------------- Epoch 99 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6524204
# adversarial loss  : 0.7454673
# --------------- Epoch 100 ---------------
# 99% [*************************************************]
#
# discriminator loss: 0.6555678
# adversarial loss  : 0.6770071

# %%
import matplotlib.pyplot as plt

#表示するサンプル数
examples=100
#潜在空間からサンプリング
noise = np.random.normal(0, 1, size=[examples, latent_dim])
#画像を生成
generatedImages = generator.predict(noise)

c = (generatedImages - np.min(generatedImages))/np.ptp(generatedImages)

dim=(10, 10)
plt.figure(figsize=(10, 10))
for i in range(c.shape[0]):
    plt.subplot(dim[0], dim[1], i+1)
    plt.imshow(c[i].reshape(height, width, channels), interpolation='nearest', cmap='gray', vmax=1, vmin=0)
    plt.axis('off')
plt.tight_layout()
